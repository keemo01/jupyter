# %% [markdown]
# # HeapSort Algorithm
# by Akeem Jokosenumi
# Student ID: G00366442

# %% [markdown]
# # What is a Heapsort Algorithm
#
# #### In computer science, heapsort is a comparison-based sorting algorithm. Like selection sort, heapsort divides its input into a sorted and an unsorted region, then gradually reduces the unsorted half by removing the largest element from it and putting it into the sorted zone.

# %% [markdown]
# # Data Structures and Algorithms

# %% [markdown]
# In order to comprehend the heap sort algorithm, we first need to grasp what an algorithm in computer science is. According to Wikipedia, an algorithm is ["a finite sequence of well-defined instructions, often used to solve a class of particular problems or to conduct a computation."] (https://en.wikipedia.org/wiki/Algorithm) [1]
#
# Meaningful algorithms provide you with the solution to a certain problem. In this situation, data structures and their operations are defined by algorithms.
#
# A ["management, and storage format that permits efficient access and modification"] is a data structure. Wikipedia states (https://en.wikipedia.org/wiki/Data struOne sorting algorithm, heap sort, is among the most well-known since it performs the best andcture)[2].
#
# Combining these two, algorithms use these data structures to decide how data is organized.
#
# One sorting algorithm, heap sort, is among the most well-known since it performs the best and worst case scenario can be both [O(n log n)]

# %% [markdown]
# # Heap

# %% [markdown]
# Heap sort is a comparison-based sorting technique based on Binary Heap data structure.
#
# For starters, let's define a Complete Binary Tree. A full binary tree is a binary tree in which every level, except possibly the last, is completely filled, and all nodes are as far left as possible (Here's my source on the [Wikipedia](https://en.wikipedia.org/wiki/Binary_tree#Types_of_binary_trees)).
#
# A [Binary heap](https://www.geeksforgeeks.org/binary-heap/) is a complete binary tree in which the values of the nodes are arranged in such a way that the parent node's value is larger (or lower) than the values of the two child nodes. The former is known as the max heap, whereas the latter is known as the min-heap. An array or binary tree can be used to represent the heap, And the two children must satisfy two properties.
#
# The first one is a structural property. This tree is satisfied by being complete its completed when " A heap with height of H is a complete binary tree if each level has max number of nodes possible, and the remaining nodes at level H dwell in the furthest position left available on that level" is how this tree is satisfied by being complete.
#
# The second is called heap order which can be decribed as the parent node is less than or equal to the kid node which = <b>Min.heap</b>.
# The parent node is greater than or equal to a kid node = <b>Max.heap</b>.
#
# So this makes it that the root node of the tree is either the smallest or largest element in this data structure and the heap sort Algorithm itself uses a <b>Max Heap</b>

# %% [markdown]
# ##### Completed binary tree

# %% [markdown]
# A complete binary tree is a binary tree in which all the levels are completely filled except possibly the lowest one, which is filled from the left. A complete binary tree is just like a full binary tree, but with two major differences. All the leaf elements must lean towards the left.

# %% [markdown]
# ![binary%20tree.jpg](attachment:binary%20tree.jpg)

# %% [markdown]
# ## Maximum and Minimum heap

# %% [markdown]
# ![MaxMinHeap.png](attachment:MaxMinHeap.png)

# %% [markdown]
# On the left side of the diagram we have the <b> Min Heap</b> the parent node here must be less than or equal to the value of the kid nodes whilst the parent node has the smallest value this is called the <b> Min Heap</b>
#
# On the right side of the diagram we have the <b> Max Heap</b> the parent node here must be greater than or equal to the value of the kid nodes whilst the parent node has the largest value this is called the <b> Max Heap</b>

# %% [markdown]
# ## Finding the parent and kid nodes

# %% [markdown]
# A Binary Heap can be easily represented as an array because it is a Complete Binary Tree, and the array-based representation is space efficent. The left child can be calculated by multiplying by 2 * I + 1 and the right child by 2 * I + 2 if the parent node is stored at index I. (assuming the indexing starts at 0).

# %% [markdown]
# ![nodes.jpg](attachment:nodes.jpg)

# %% [markdown]
# Index number are coloured in <b>Blue</b> and the int value within are coloured <b>WHITE</b>.
#
# In the diagram, above the node with the value 3 inside has the index of 1. i= 1
#
# Find children:
# <b>Left Child</b>of index 1: (2xi)+1 = (2x1)+1= 3 index. <br>
# <b>Right Child</b> of index 1: (2xi)+2 = (2x1)+2 = 4 index.
#
#
# This shows that index 3 with the value 5 is the left child of index 1. <br>
# Index 4 with value 9 is the right child to index 1. <br>
#
# To find the parent of index 3 and 4:
#
#
# Parent of index 3: floor((i-1)÷2) = floor((3-1)÷2) = floor(1) = index 1.<br>
#
#
# Parent of index 4: floor((i-1)÷2) = floor((4-1)÷2) = floor(1.5) = index 1.
#
# This shows that index 3 & 4 parent is index 1.

# %% [markdown]
# # Binary Tree

# %% [markdown]
# ![binary%20trees.png](attachment:binary%20trees.png)

# %% [markdown]
# A binary tree in computer science is a tree data structure in which each node has at most two children, which are referred to as the left child and the right child who are siblings.
#
# The Types of nodes:
# - Root Node: the one located at the top of the tree.
# - child node: A sub-node that is connected by an edge from a parent node.
# - parent node:  Any nodes (excluding the root) that has at least one child node (sub-node).
# - leaf node: Descendants of a parent node.
#
#
# <br><b>Summary</b></br>
# After defining heap, binary tree, and min/max heaps, let's go on. Now I can talk about how these relate to the heap sort method. Because it uses the binary heap data format, the heap sort algorithm uses comparisons to determine the order of items. The algorithm I demonstrated above for discovering child nodes is used by heap sort to create a max-heap. The binary tree's root element and the node with the lowest value at the end are then switched using heapsort. Next, it subtracts 1 from the heap. then continues until the heap is completely empty. A step-by-step example is provided at the end of this notebook.

# %% [markdown]
# # Implementation of Heap Sort

# %% [markdown]
# When it comes to the Heap Sort Algorithm there are two main functions Heapsort and Heapify

# %% [markdown]
# <br><b>Heapify</b></br>
# Heapify is the process of creating a heap data structure from a binary tree. It is used to create a Min-Heap or a Max-Heap. Let the input array be Initial Array. Create a complete binary tree from the array Complete binary tree. Start from the first index of non-leaf node whose index is given by n/2 - 1.
#
# <br><b>Heapsort</b></br>
# Once the tree is a max heap preform these actions
#
# - Build a max heap from the input data.
# - At this point, the largest item is stored at the root of the heap. Replace it with the last item of the heap followed by reducing the size of heap by 1. Finally, heapify the root of the tree.
# - Repeat step 2 while the size of the heap is greater than 1.

# %%
def heapify(array, length, parent): # array, length, root
    
    # Find the biggest value among root and children
    biggest = parent
    
    # Finding the children of the root.
    left = 2 * parent + 1
    
    right = 2 * parent + 2

    # check if the left child of the root is there and if it is greater value than the root
    if left < length and array[parent] < array[left]:
        
        biggest = left

    # check if the right child of the root is there and if it is greater value than the root
    if right < length and array[biggest] < array[right]:
        
        biggest = right

    # we must check If the parent is not the largest, swap and proceed to heapify
    if (biggest != parent):
        
        array[parent], array[biggest] = array[biggest], array[parent]

        # re-call function 
        heapify(array, length, biggest)

# %%
def heapSort(array): 
    
    # gets the size of the array being passed down
    s = len(array) 
  
    
    # goes through the values and heapifys them. The resulting list of elements will be a max heap
    for i in range(s//2, -1, -1):  # s//2 floors the value
        
        heapify(array, s, i) 
  
    # One by one extract elements 
    for i in range(s-1, 0, -1): 
        
        #swaps
        array[i], array[0] = array[0], array[i] 

        #Heapify root 
        heapify(array, i, 0)

# %%
# Example result

array = [100,43,21,9,2,19,1,70,68,55,50]

print("Array before heapsort:")
print(array)# prints array before going through heapsort function

print("Array after heapsort:")


size = len(array) # gets length of array

heapSort(array)# calls function on array

for i in range(size):
    print("%d " % array[i], end='') # prints out the array after going through heapsort
# Out:
# Array before heapsort:
# [100, 43, 21, 9, 2, 19, 1, 70, 68, 55, 50]
# Array after heapsort:
# 1 2 9 19 21 43 50 55 68 70 100

# %% [markdown]
# <br>
#
# ## Heap Sort Algorithm Complexity

# %% [markdown]
# Heapsort has a running time of O(n\log n)O(nlogn).

# %% [markdown]
# ![Big%20O.png](attachment:Big%20O.png)

# %% [markdown]
# ![input.png](attachment:input.png)

# %% [markdown]
# The best case and worst case performances of heapsort are both O (n log n). Which means that compared to other sorting algorithms, it has the benefit of a more favourable worst-case O(n log n) runtime.

# %% [markdown]
# # How is Heapsort with its Time Complexity

# %% [markdown]
# The heapsort algorithm itself has O(n log n) time complexity using either version of heapify.
#
# <b>The Space Complexity</b><br>
# Space complexity refers to the total amount of memory space used by an algorithm/program, including the space of input values for execution. Calculate the space occupied by variables in an algorithm/program to determine space complexity. However, people frequently confuse Space-complexity with auxiliary space

# %% [markdown]
# ## Heap Sort vs Other Sorting Algorithms

# %% [markdown]
# ![quicksort.webp](attachment:quicksort.webp)

# %% [markdown]
# From the diagram above we can see that HeapSort it is the slowest of the sorting algorithms but unlike merge and quick sort it does not require massive recursion or multiple arrays to work.

# %% [markdown]
# <b>Heapsort vs Mergesort</b><br>
# The merge sort requires additional space. The heapsort may be implemented using additional space, but does not require it. Heapsort, however, is unstable, in that it doesn't guarantee to leave 'equal' elements unchanged. If you test both methods fairly and under the same conditions, the differences will be minimal

# %% [markdown]
# <b>Heapsort vs Quicksort</b><br>
# Heapsort is typically somewhat slower than quicksort, but the worst-case running time is always Θ(nlogn). Quicksort is usually faster, though there remains the chance of worst case performance except in the introsort variant, which switches to heapsort when a bad case is detected.

# %% [markdown]
# <b>Overview</b><br>
# The Heapdort algorithm shows consistent performances and because of this its particularly suitable to use in systems with a vital response time.

# %% [markdown]
# ## Implementaion of Heapsort vs Mergesort and Quicksort

# %% [markdown]
# <b>Merge sort</b>

# %%
def mergeSort(myList):
    if len(myList) > 1:
        mid = len(myList) // 2
        left = myList[:mid]
        right = myList[mid:]

        # Recursive call on each half
        mergeSort(left)
        mergeSort(right)

        # Two iterators for traversing the two halves
        i = 0
        j = 0
        
        # Iterator for the main list
        k = 0
        
        while i < len(left) and j < len(right):
            if left[i] <= right[j]:
              # The value from the left half has been used
              myList[k] = left[i]
              # Move the iterator forward
              i += 1
            else:
                myList[k] = right[j]
                j += 1
            # Move to the next slot
            k += 1

        # For all the remaining values
        while i < len(left):
            myList[k] = left[i]
            i += 1
            k += 1

        while j < len(right):
            myList[k]=right[j]
            j += 1
            k += 1

# %% [markdown]
# <b>Quicksort</b>

# %%
def partition(arr, lowPoint, high):
    i = (lowPoint-1)         # index of smaller element
    pivot = arr[high]     # pivot
 
    for j in range(lowPoint, high):
 
        # If current element is smaller than or
        # equal to pivot
        if arr[j] <= pivot:
 
            # increment index of smaller element
            i = i+1
            arr[i], arr[j] = arr[j], arr[i]
 
    arr[i+1], arr[high] = arr[high], arr[i+1]
    return (i+1)
 
# The main function that implements QuickSort
# arr[] --> Array to be sorted,
# low  --> Starting index,
# high  --> Ending index
 
# Function to do Quick sort
 
 
def quickSort(arr, lowPoint, high):
    if len(arr) == 1:
        return arr
    if lowPoint < high:
 
        # pi is partitioning index, arr[p] is now
        # at right place
        pi = partition(arr, lowPoint, high)
 
        # Separately sort elements before
        # partition and after partition
        quickSort(arr, lowPoint, pi-1)
        quickSort(arr, pi+1, high)

# %% [markdown]
# ## Comparison

# %%
from timeit import default_timer as timer

# list array for all 3 sorting algorithms
myList = [23,56,0,23,85,100,200,12,32]

n = len(myList) # gets the size of array

#Output of original list
print("Original list:")
for i in range(n):
    print("%d " % myList[i], end='')

# getting the time
start=timer();
heapSort(myList)
end=timer();

#final time
time1=end-start

#Output sorted list
print("\n\n Heap Sort= Sorted list:")
for i in range(n):
  print("%d " % myList[i], end='')

print("\n\nTime to finish: \n", time1)
# Out:
# Original list:
# 54 26 93 17 77 31 44 55 20
#
#  Heap Sort= Sorted list:
# 17 20 26 31 44 54 55 77 93
#
# Time to finish:
#  0.0001474999999118154

# %%
# list array for all 3 sorting algorithms
myL = [23,56,0,23,85,100,200,12,32]

#getting the time
s=timer();
mergeSort(myL)
e=timer();

#final time
time2=e-s

#Output sorted list
print("\n\n Merge Sort = Sorted list:")
for i in range(n):
  print("%d " % myL[i], end='')

print("\n\nTime to finish: \n", time2)
# Out:
#  Merge Sort = Sorted list:
# 0 12 23 23 32 56 85 100 200
#
# Time to finish:
#  0.0002849000002242974

# %%
# list array for all 3 sorting algorithms
myA = [23,56,0,23,85,100,200,12,32]

#getting the time
s1=timer();
quickSort(myA, 0, n-1)
e1=timer();

#final time
time3=e1-s1

#Output sorted list
print("\n\n Quick Sort = Sorted list:")
for i in range(n):
  print("%d " % myA[i], end='')

print("\n\nTime to finish: \n", time3)
# Out:
#  Quick Sort = Sorted list:
# 0 12 23 23 32 56 85 100 200
#
# Time to finish:
#  0.00023599999985890463

# %% [markdown]
# ## A Graph that visualises what happens in the Heap-Sort Algorithm

# %%
#imports
import matplotlib.pyplot as plt
import networkx as nx
import math

def drawtree(L, highlight=None):
    # Create a fully balanced binary tree.
  T = nx.balanced_tree(2, math.floor(math.log(len(L), 2)))
  
    # Remove nodes beyond the length of L.   
  T.remove_nodes_from(list(T.nodes)[len(L):])
  
    # Relabel the nodes with elements of L.
  T = nx.relabel_nodes(T, dict(zip(T.nodes, L)), copy=True)
  
    # Get nice positions for the nodes in the picture.
  pos = nx.drawing.nx_pydot.graphviz_layout(T, prog="dot")
  
    # Draw the graph.
  nx.draw(T, pos, with_labels=True, node_color='lightgrey', node_size=1600, font_size=32)
  
    # Highlight nodes if needed.
  if highlight:
    nx.draw_networkx(T.subgraph([i for i in T.nodes if i in highlight]), pos=pos, node_color='pink', node_size=1600, font_size=32)

#List
L = [20,12,17,5,8,11,3]

#Print the Array
print(L)

#Draw tree from L
draw(L)
# Out:
# [20, 12, 17, 5, 8, 11, 3]

# %% [markdown]
# This is an array of integers in a graph format when it goes through heapsort its put through heapify first which makes it into a Max Heap

# %%
L =[90,80,70,40,30,20,10]
draw(L,[90,10])

# %%
L =[10,20,30,40,70,80,90]
draw(L,[10,90])

# %% [markdown]
# When swapped the value 90 which is now the last node is going to be removed before the next heapify

# %%
L =[10,20,30,40,70,80]
draw(L)

# %% [markdown]
# After being removed, the final node, which now has the greatest value, is heapified once more. The vaules are cut off and sorted in this manner until then.

# %%
L =[90,80,70,40,30,20]
draw(L)

# %% [markdown]
# Heapify done the 2nd time repeat this until you get results shown below

# %%
L = [90, 80, 70, 40, 30, 20, 10]

n = len(L)

print("Before:", L)
for i in range(n):
    print("After:")

heapSort(L)

print("After:", L)

draw(L)
# Out:
# Before: [90, 80, 70, 40, 30, 20, 10]
# After:
# After:
# After:
# After:
# After:
# After:
# After:
# After: [10, 20, 30, 40, 70, 80, 90]

# %% [markdown]
# This is the graph when its been heapsorted small error there but can be fixed lol anyways thanks to the graphs i was able to show and explain the heap-sort algorithm

# %% [markdown]
# # References

# %% [markdown]
# Data Structure https://en.wikipedia.org/wiki/Data_structure<br>
# Heap Sort https://www.geeksforgeeks.org/heap-sort/<br>
# Merge Sort https://linuxhint.com/merge-sort-python/<br>
# Binary tree https://www.youtube.com/watch?v=H5JubkIy_p8<br>
# Binary tree https://www.youtube.com/watch?v=fAAZixBzIAI<br>
# merge sort https://www.geeksforgeeks.org/merge-sort/ <br>
#  McLoughlin, “Using git for assessments,” https://github.com/ianmcloughlin/using-git-for-assessments/<br>
#  GMIT, “Quality assurance framework,” https://www.gmit.ie/general/quality-assurance-framework<br>
# heapsort o(n log n) https://www.quora.com/How-does-Heapsort-take-O-nlogn-time <br>
# https://www.programiz.com/dsa/heap-sort<br>
